# %%
# Artificial Neural Network


# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

## Concatenate the Data Frames

X=pd.concat([X,geography,gender],axis=1)

## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout


# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(output_dim = 6, init = 'he_uniform',activation='relu',input_dim = 11))

# Adding the second hidden layer
classifier.add(Dense(output_dim = 6, init = 'he_uniform',activation='relu'))
# Adding the output layer
classifier.add(Dense(output_dim = 1, init = 'glorot_uniform', activation = 'sigmoid'))
# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 100, nb_epoch = 30)

# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)

y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:51: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=11, units=6, kernel_initializer="he_uniform")`
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:54: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=6, kernel_initializer="he_uniform")`
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:56: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="glorot_uniform")`
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:61: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 5359 samples, validate on 2641 samples
# Epoch 1/30
# 5359/5359 [==============================] - 1s 145us/step - loss: 0.6659 - accuracy: 0.6055 - val_loss: 0.6331 - val_accuracy: 0.6475
# Epoch 2/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.5974 - accuracy: 0.7063 - val_loss: 0.5865 - val_accuracy: 0.7368
# Epoch 3/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.5641 - accuracy: 0.7548 - val_loss: 0.5609 - val_accuracy: 0.7618
# Epoch 4/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.5439 - accuracy: 0.7770 - val_loss: 0.5445 - val_accuracy: 0.7736
# Epoch 5/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.5299 - accuracy: 0.7862 - val_loss: 0.5323 - val_accuracy: 0.7834
# Epoch 6/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.5189 - accuracy: 0.7921 - val_loss: 0.5230 - val_accuracy: 0.7880
# Epoch 7/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.5103 - accuracy: 0.7929 - val_loss: 0.5153 - val_accuracy: 0.7895
# Epoch 8/30
# 5359/5359 [==============================] - 0s 29us/step - loss: 0.5031 - accuracy: 0.7942 - val_loss: 0.5090 - val_accuracy: 0.7925
# Epoch 9/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.4970 - accuracy: 0.7947 - val_loss: 0.5036 - val_accuracy: 0.7929
# Epoch 10/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.4918 - accuracy: 0.7955 - val_loss: 0.4988 - val_accuracy: 0.7933
# Epoch 11/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.4869 - accuracy: 0.7957 - val_loss: 0.4945 - val_accuracy: 0.7940
# Epoch 12/30
# 5359/5359 [==============================] - 0s 29us/step - loss: 0.4827 - accuracy: 0.7959 - val_loss: 0.4904 - val_accuracy: 0.7948
# Epoch 13/30
# 5359/5359 [==============================] - 0s 31us/step - loss: 0.4786 - accuracy: 0.7964 - val_loss: 0.4869 - val_accuracy: 0.7955
# Epoch 14/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.4750 - accuracy: 0.7966 - val_loss: 0.4835 - val_accuracy: 0.7959
# Epoch 15/30
# 5359/5359 [==============================] - 0s 31us/step - loss: 0.4718 - accuracy: 0.7968 - val_loss: 0.4805 - val_accuracy: 0.7952
# Epoch 16/30
# 5359/5359 [==============================] - 0s 33us/step - loss: 0.4688 - accuracy: 0.7979 - val_loss: 0.4776 - val_accuracy: 0.7948
# Epoch 17/30
# 5359/5359 [==============================] - 0s 30us/step - loss: 0.4660 - accuracy: 0.7981 - val_loss: 0.4752 - val_accuracy: 0.7967
# Epoch 18/30
# 5359/5359 [==============================] - 0s 31us/step - loss: 0.4635 - accuracy: 0.7994 - val_loss: 0.4728 - val_accuracy: 0.7963
# Epoch 19/30
# 5359/5359 [==============================] - 0s 32us/step - loss: 0.4611 - accuracy: 0.7994 - val_loss: 0.4707 - val_accuracy: 0.7963
# Epoch 20/30
# 5359/5359 [==============================] - 0s 36us/step - loss: 0.4588 - accuracy: 0.7987 - val_loss: 0.4687 - val_accuracy: 0.7967
# Epoch 21/30
# 5359/5359 [==============================] - 0s 36us/step - loss: 0.4567 - accuracy: 0.7992 - val_loss: 0.4669 - val_accuracy: 0.7978
# Epoch 22/30
# 5359/5359 [==============================] - 0s 39us/step - loss: 0.4547 - accuracy: 0.7992 - val_loss: 0.4652 - val_accuracy: 0.7978
# Epoch 23/30
# 5359/5359 [==============================] - 0s 25us/step - loss: 0.4528 - accuracy: 0.7992 - val_loss: 0.4635 - val_accuracy: 0.7970
# Epoch 24/30
# 5359/5359 [==============================] - 0s 36us/step - loss: 0.4510 - accuracy: 0.8015 - val_loss: 0.4621 - val_accuracy: 0.7982
# Epoch 25/30
# 5359/5359 [==============================] - 0s 36us/step - loss: 0.4494 - accuracy: 0.8013 - val_loss: 0.4607 - val_accuracy: 0.7997
# Epoch 26/30
# 5359/5359 [==============================] - 0s 34us/step - loss: 0.4477 - accuracy: 0.8020 - val_loss: 0.4594 - val_accuracy: 0.7989
# Epoch 27/30
# 5359/5359 [==============================] - 0s 32us/step - loss: 0.4461 - accuracy: 0.8015 - val_loss: 0.4580 - val_accuracy: 0.7993
# Epoch 28/30
# 5359/5359 [==============================] - 0s 32us/step - loss: 0.4446 - accuracy: 0.8028 - val_loss: 0.4567 - val_accuracy: 0.7986
# Epoch 29/30
# 5359/5359 [==============================] - 0s 34us/step - loss: 0.4430 - accuracy: 0.8029 - val_loss: 0.4554 - val_accuracy: 0.7989
# Epoch 30/30
# 5359/5359 [==============================] - 0s 37us/step - loss: 0.4414 - accuracy: 0.8037 - val_loss: 0.4541 - val_accuracy: 0.8001
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])
